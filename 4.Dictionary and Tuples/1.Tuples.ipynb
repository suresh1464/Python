# %%
point = (5,6)
point[0]
# Out:
# 5

# %%
point[1]
# Out:
# 6

# %%
type(point)
# Out:
# tuple

# %%
# Tuples are immutable where as lists are mutable- You can add or delete value
# List are dynamically will grow
point[1] = 7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Tuples are immutable where as lists are mutable- You can add or delete value
# ----> 2 point[1] = 7
#
# TypeError: 'tuple' object does not support item assignment

# %%
point_3d = (5,8,10)
point_3d
# Out:
# (5, 8, 10)

# %%
def find_pe_and_pb(price,eps,book_value):
    pe = price/eps
    pb = price/book_value
    return [pe,pb]   # List is created here

# %%
val = find_pe_and_pb(100,2,4)
val
# Out:
# [50.0, 25.0]

# %%
val[0]
# Out:
# 50.0

# %%
val[1]
# Out:
# 25.0

# %%
def find_pe_and_pb(price,eps,book_value):
    pe = price/eps
    pb = price/book_value
    return pe,pb   # Tuple is created here

# %%
pe_ratio,pb_ratio = find_pe_and_pb(100,2,4)

# %%
pe_ratio
# Out:
# 50.0

# %%
pb_ratio
# Out:
# 25.0
