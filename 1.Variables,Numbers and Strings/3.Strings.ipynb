# %%
# String can be initialize with single or double quotes
First = "Aarush"
Last = 'Siva'
type(First)
# Out:
# str

# %%
name = First + " " + Last
name
# Out:
# 'Aarush Siva'

# %%
name = f"{First} {Last}"
name
# Out:
# 'Aarush Siva'

# %%
age = 11
info = f"{First} {Last} is {age} years old"
info
# Out:
# 'Aarush Siva is 11 years old'

# %%
name[0]
# Out:
# 'A'

# %%
name[2]
# Out:
# 'r'

# %%
name[0:6]
# Out:
# 'Aarush'

# %%
name[7:len(name)]
# Out:
# 'Siva'

# %%
name
# Out:
# 'Aarush Siva'

# %%
name[-1]
# Out:
# 'a'

# %%
name[0] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 name[0] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %%
# Sting objects are immutable. We can't change the values once assigned. But you can re-assign with new value

# %%
food_story = "Aarush's favourite food is Biriyani"
food_story
# Out:
# "Aarush's favourite food is Biriyani"

# %%
s = 'He said "oops"'
s
# Out:
# 'He said "oops"'

# %%
s = "He said "oops"" # Python will think that string is ending here
s
# Out:
#   Cell In[41], line 1
#     s = "He said "oops""
#                   ^
# SyntaxError: invalid syntax

# %%
recipe = "Veg biriyani with saffron,cardamom,and cloves,garnished with fried onions and cilantro"
recipe
# Out:
# 'Veg biriyani with saffron,cardamom,and cloves,garnished with fried onions and cilantro'

# %%
# ''' to represent paragraph
recipe = '''
Veg biriyani with saffron,cardamom,and cloves,garnished with fried onions 
and cilantro
'''
recipe
# Out:
# '\nVeg biriyani with saffron,cardamom,and cloves,garnished with fried onions \nand cilantro\n'

# %%
print(recipe)
# Out:
# Veg biriyani with saffron,cardamom,and cloves,garnished with fried onions
# and cilantro

# %%
spice = 'cardamom'
spice in recipe
# Out:
# True

# %%
"milk" in recipe
# Out:
# False

# %%
recipe.find(spice)
# Out:
# 27

# %%
#Functions in String
dir(recipe)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
s = "patient was charged for $100 for lab test"
s
# Out:
# 'patient was charged for $100 for lab test'

# %%
s.replace("100","200") # Its assigned a value but not replaced in actual string
# Out:
# 'patient was charged for $200 for lab test'

# %%
s
# Out:
# 'patient was charged for $100 for lab test'

# %%
s1 = s.replace("100","200")

# %%
s1
# Out:
# 'patient was charged for $200 for lab test'

# %%
s.upper()
# Out:
# 'PATIENT WAS CHARGED FOR $100 FOR LAB TEST'

# %%
'410'.isdigit()
# Out:
# True

# %%
'410a'.isdigit()
# Out:
# False

# %%
s.index("$100")
# Out:
# 24

# %%
text = "my age is:"
age = 40
text + age
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 3
#       1 text = "my age is:"
#       2 age = 40
# ----> 3 text + age
#
# TypeError: can only concatenate str (not "int") to str

# %%
text + str(age)
# Out:
# 'my age is:40'

# %%
s = "Hey\tBro"
s
# Out:
# 'Hey\tBro'

# %%
print(s)
# Out:
# Hey	Bro

# %%
tickers = "APPL|NVDA|RIL|GOGL"  #Shift + Tab
tickers.split("|",maxsplit=2)
# Out:
# ['APPL', 'NVDA', 'RIL|GOGL']

# %%
data = " Hey, we have to go there, you coming der ? "
data
# Out:
# ' Hey, we have to go there, you coming der ? '

# %%
data.strip()
# Out:
# 'Hey, we have to go there, you coming der ?'

# %%
file_name = "report.pdf"
file_name.endswith(".pdf")
# Out:
# True

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
fruits = "apple,orange"
vegetables = 'Carrot,potato'
print(f"I eat {vegetables} vegetables and {fruits} fruits daily.")
# Out:
# I eat Carrot,potato vegetables and apple,orange fruits daily.

# %%
string1 = "The Himalayas are one of the youngest mountain range on the planet."
string1
# Out:
# 'The Himalayas are one of the youngest mountain range on the planet.'

# %%
string1[0:13]
# Out:
# 'The Himalayas'

# %%
string1[-29:-15]
# Out:
# 'mountain range'

# %%
string1[-15:]
# Out:
# ' on the planet.'

# %%
string1[0:13] + string1[-15:]
# Out:
# 'The Himalayas on the planet.'

# %%
print(f"{string1[0:13]} {string1[-14:]}")
# Out:
# The Himalayas on the planet.

# %%
str1 = "There are 9 planet in the solar system"
str1
# Out:
# 'There are 9 planet in the solar system'

# %%
str1 = str1.replace("9","8")
str1
# Out:
# 'There are 8 planet in the solar system'

# %%
str1 = str1.replace("planet","planets")
str1
# Out:
# 'There are 8 planets in the solar system'

# %%
s = "datascience"
print(s[1:5])
# Out:
# atas

# %%
5+4*3
# Out:
# 17

# %%
-9 % 2
# Out:
# 1
