# %%
#Variable are containers that stores data

# %%
Can = "soda"
Can
# Out:
# 'soda'

# %%
Can = 'Beans'
Can
# Out:
# 'Beans'

# %%
type(Can)
# Out:
# str

# %%
pizza = 100
samosa = 20.5
ice_cream = 150

# %%
total = pizza + samosa + ice_cream
total
# Out:
# 270.5

# %%
type(pizza)
# Out:
# int

# %%
type(total)
# Out:
# float

# %%
foo = 'Jilebi'
foo
# Out:
# 'Jilebi'

# %%
bar = foo
bar
# Out:
# 'Jilebi'

# %%
print(bar)
# Out:
# Jilebi

# %%
print(foo)
# Out:
# Jilebi

# %%
id(foo)
# Out:
# 5750664400

# %%
id(bar)
# Out:
# 5750664400

# %%
bar = 'Ice Cream'
bar
# Out:
# 'Ice Cream'

# %%
id(bar)
# Out:
# 5729561072

# %%
#You cann't use reserved key words
#You cann't use special characters
#Variable name must start with _ or Letter(L/U)
