# %%
First = "Aarush"
Last = 'Siva'
type(First)
# Out:
# str

# %%
name = First + " " + Last
name
# Out:
# 'Aarush Siva'

# %%
name = f"{First} {Last}"
name
# Out:
# 'Aarush Siva'

# %%
age = 11
info = f"{First} {Last} is {age} years old"
info
# Out:
# 'Aarush Siva is 11 years old'

# %%
name[0]
# Out:
# 'A'

# %%
name[2]
# Out:
# 'r'

# %%
name[0:6]
# Out:
# 'Aarush'

# %%
name[7:len(name)]
# Out:
# 'Siva'
