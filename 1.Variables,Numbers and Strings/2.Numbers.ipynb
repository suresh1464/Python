# %%
length = 10
height = 7
area = (length * height)/2
area
# Out:
# 35.0

# %%
type(area)
# Out:
# float

# %%
x = 10
y = 7

# %%
x+y
# Out:
# 17

# %%
x - y
# Out:
# 3

# %%
x / y
# Out:
# 1.4285714285714286

# %%
x // y
# Out:
# 1

# %%
x % y
# Out:
# 3

# %%
x ** y
# Out:
# 10000000

# %%
10+2*3
# Out:
# 16

# %%
(10+2)*3
# Out:
# 36

# %%
#Scientific Notation
1e4
# Out:
# 10000.0

# %%
foo = 2.3e4
foo
# Out:
# 23000.0

# %%
1e-4
# Out:
# 0.0001

# %%
bar = 2.3e-4

# %%
bar
# Out:
# 0.00023

# %%
a = 100.4356
round(a)
# Out:
# 100

# %%
round(a,2)
# Out:
# 100.44

# %%
food = "120.34"
rent = "500.67"
total = food + rent
total
# Out:
# '120.34500.67'

# %%
#convert string to float
total = float(food) + float(rent)
total
# Out:
# 621.01

# %%
import math
x = 25
math.sqrt(x)
# Out:
# 5.0

# %%
math.floor(4.6)
# Out:
# 4

# %%
math.ceil(4.6)
# Out:
# 5

# %%
math.floor(4.5)
# Out:
# 4

# %%
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
format(5,'b')  # Number display in binary format
# Out:
# '101'
